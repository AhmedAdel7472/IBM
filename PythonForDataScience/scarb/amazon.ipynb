# %%
import pandas as pd
from selenium import webdriver

# %%
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.amazon.eg/s?k=samsung&language=en_AE&crid=14PRZ40MBTY5Z&sprefix=samsung%2Caps%2C160&ref=nb_sb_noss_1')

# %%
titles=driver.find_elements(By.XPATH,'//span[@class="a-size-base-plus a-color-base a-text-normal"]')

# %%
titles
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fbf7c2adca3e961866803813eb40f591", element="f.6CD8F2CD8056B75A984F9764E9905D07.d.9D157C90A0BD2B2F6C497F3AB6D90790.e.211")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fbf7c2adca3e961866803813eb40f591", element="f.6CD8F2CD8056B75A984F9764E9905D07.d.9D157C90A0BD2B2F6C497F3AB6D90790.e.212")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fbf7c2adca3e961866803813eb40f591", element="f.6CD8F2CD8056B75A984F9764E9905D07.d.9D157C90A0BD2B2F6C497F3AB6D90790.e.213")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fbf7c2adca3e961866803813eb40f591", element="f.6CD8F2CD8056B75A984F9764E9905D07.d.9D157C90A0BD2B2F6C497F3AB6D90790.e.214")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fbf7c2adca3e961866803813eb40f591", element="f.6CD8F2CD8056B75A984F9764E9905D07.d.9D157C90A0BD2B2F6C497F3AB6D90790.e.215")>,
# ...

# %%
for i in titles:
    print(i.text)
# Out:
# Galaxy S24, AI Android Smartphone, 256GB Storage, 8GB RAM, 50MP Camera, Long Battery Life, Amber Yellow - 1 year Local Warranty
# Wireless Car Charger EP-H5300, Black
# Galaxy A15 Dual SIM 8GB Ram+256GGB ROM (6.5 Inches) (4G LTE) - (Blue Black)
# Galaxy A25 5G, 6GB RAM, 128GB Storage, Light Blue
# Galaxy A05s, Android Smartphone, Dual SIM Mobile Phone, LTE, 4GB RAM, 128GB Storage, Black
# Galaxy A05s LTE, 6GB RAM, 128GB Storage, Silver
# Galaxy A15 Dual SIM 6GB Ram+128GB ROM (6.5 Inches) (4G LTE) - (Black Blue )
# Galaxy A55 5G, Android Smartphone, Dual SIM Mobile Phone, 8GB RAM, 256GB Storage, Awesome Navy - 1 year Warranty
# Galaxy A15 Dual SIM 6GB Ram+128GB ROM (6.5 Inches) (4G LTE) - (Light Blue)
# Galaxy A15 Dual SIM 8GB Ram+256GGB ROM (6.5 Inches) (4G LTE) - (Light Blue)
# Galaxy A05s, Android Smartphone, Dual SIM Mobile Phone, LTE, 4GB RAM, 128GB Storage, Silver
# Galaxy A25 Dual SIM (5G) 8GB RAM+256GB Storage (Light Blue)
# ...

# %%
price=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')

# %%
price
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fbf7c2adca3e961866803813eb40f591", element="f.6CD8F2CD8056B75A984F9764E9905D07.d.9D157C90A0BD2B2F6C497F3AB6D90790.e.271")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fbf7c2adca3e961866803813eb40f591", element="f.6CD8F2CD8056B75A984F9764E9905D07.d.9D157C90A0BD2B2F6C497F3AB6D90790.e.272")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fbf7c2adca3e961866803813eb40f591", element="f.6CD8F2CD8056B75A984F9764E9905D07.d.9D157C90A0BD2B2F6C497F3AB6D90790.e.273")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fbf7c2adca3e961866803813eb40f591", element="f.6CD8F2CD8056B75A984F9764E9905D07.d.9D157C90A0BD2B2F6C497F3AB6D90790.e.274")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fbf7c2adca3e961866803813eb40f591", element="f.6CD8F2CD8056B75A984F9764E9905D07.d.9D157C90A0BD2B2F6C497F3AB6D90790.e.275")>,
# ...

# %%
for i in price:
    print(i.text)
# Out:
# 45,499
# 2,499
# 8,499
# 10,499
# 5,499
# 6,149
# 7,099
# 17,242
# 7,099
# 8,499
# 5,577
# 10,799
# 6,299
# 6,600
# 9,250
# 16,550
# 7,333
# 10,900
# 21,999
# 790
# 505
# 1,640
# 900
# 11,999
# 7,999
# 9,328
# 17,990
# 9,333
# 38,450
# 13,199
# 47,550
# 17,499
# 16,550
# 9,333
# 15,850
# 22,999
# 10,900
# 62,500
# 21,449
# 19,999
# 23,499
# 14,499
# 27,500
# 29,999
# 13,990
# 6,100
# 24,999
# 950
# 1,555
# 250
# 160
# 198
# 200

# %%
len(price)
# Out:
# 53

# %%
len(titles)
# Out:
# 60

# %% [markdown]
# different lengths so we need to find the problem

# %% [markdown]
# The solution is to take the product as a whole

# %%
products=driver.find_elements(By.XPATH,'//div[@class="puis-card-container s-card-container s-overflow-hidden aok-relative puis-expand-height puis-include-content-margin puis puis-vsom9k8yemr4u1yo82zayoamev s-latency-cf-section puis-card-border"]')

# %%
products
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fbf7c2adca3e961866803813eb40f591", element="f.6CD8F2CD8056B75A984F9764E9905D07.d.9D157C90A0BD2B2F6C497F3AB6D90790.e.324")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fbf7c2adca3e961866803813eb40f591", element="f.6CD8F2CD8056B75A984F9764E9905D07.d.9D157C90A0BD2B2F6C497F3AB6D90790.e.325")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fbf7c2adca3e961866803813eb40f591", element="f.6CD8F2CD8056B75A984F9764E9905D07.d.9D157C90A0BD2B2F6C497F3AB6D90790.e.326")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fbf7c2adca3e961866803813eb40f591", element="f.6CD8F2CD8056B75A984F9764E9905D07.d.9D157C90A0BD2B2F6C497F3AB6D90790.e.327")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fbf7c2adca3e961866803813eb40f591", element="f.6CD8F2CD8056B75A984F9764E9905D07.d.9D157C90A0BD2B2F6C497F3AB6D90790.e.328")>,
# ...

# %%
for i in products:
    print(i.text)
# Out:
# +3 colours/patterns
# Sponsored
# SAMSUNG
# Galaxy S24, AI Android Smartphone, 256GB Storage, 8GB RAM, 50MP Camera, Long Battery Life, Amber Yellow - 1 year Local Warranty
# 35
# EGP45,499
# 00
# Get it as soon as tomorrow, 15 Sep
# Fulfilled by Amazon - FREE Shipping
# Add to cart
# Sponsored
# SAMSUNG
# Wireless Car Charger EP-H5300, Black
# 103
# EGP2,499
# 00
# 15% off selected Visa credit & debit cards
# Get it as soon as tomorrow, 15 Sep
# Fulfilled by Amazon - FREE Shipping
# Only 1 left in stock - order soon.
# Add to cart
# Best Seller
# SAMSUNG
# Galaxy A15 Dual SIM 8GB Ram+256GGB ROM (6.5 Inches) (4G LTE) - (Blue Black)
# 1,705
# 400+ bought in past month
# EGP8,499
# 00 List:
# EGP10,270.00
# Get it as soon as tomorrow, 15 Sep
# Fulfilled by Amazon - FREE Shipping
# Add to cart
# SAMSUNG
# Galaxy A25 5G, 6GB RAM, 128GB Storage, Light Blue
# 59
# EGP10,499
# 00
# Fulfilled by Amazon - FREE Shipping
# Only 3 left in stock - order soon.
# Add to cart
# SAMSUNG
# ...

# %%
elements = driver.find_elements(By.XPATH, '//span[contains(@class, "a-section a-spacing-small puis-padding-left-small puis-padding-right-small")]')

# %%
elements
# Out:
# []
